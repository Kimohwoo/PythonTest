# %%
import os
import sys
import urllib.request
import json
from nltk import Text
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from konlpy.tag import *

client_id = "6ihmHkReVtwHguO09rGp"
client_secret = "REr0Z1RsxU"
encText = urllib.parse.quote("가방")
url = "https://openapi.naver.com/v1/search/news?query=" + encText + '&display='+ str(100) # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
title = ''
description = ''
# links = []
if(rescode==200):
    response_body = response.read()
    res_body = json.loads(response_body.decode('utf-8'))
    print(res_body)
    for item in res_body['items']:
        title += item['title']
        description += item['description']
        # links.append(item['link'])
else:
    print("Error Code:" + rescode)
# Out:
# {'lastBuildDate': 'Fri, 14 Jul 2023 12:18:07 +0900', 'total': 845381, 'start': 1, 'display': 100, 'items': [{'title': '블랙핑크 지수, 프랑스 파리 일상 공개 &quot;파리는 즐거워&quot;', 'originallink': 'http://www.topstarnews.net/news/articleView.html?idxno=15367040', 'link': 'http://www.topstarnews.net/news/articleView.html?idxno=15367040', 'description': '또 다른 사진에는 큰 곰인형 모양의 <b>가방</b>을 한 쪽 어깨에 메고 거울 앞에서 포즈를 취하고 있는 지수의 모습이 담겨 있다.앞서 지수는 해외 개인 스케줄 소화를 위해 지난 11일 오전에 프랑스 파리로 출국했다.... ', 'pubDate': 'Fri, 14 Jul 2023 12:14:00 +0900'}, {'title': '이 여름 가장 패셔너블한 바스켓 백 25', 'originallink': 'https://www.vogue.co.kr/2023/07/14/%ec%9d%b4-%ec%97%ac%eb%a6%84-%ea%b0%80%ec%9e%a5-%ed%8c%a8%ec%85%94%eb%84%88%eb%b8%94%ed%95%9c-%eb%b0%94%ec%8a%a4%ec%bc%93-%eb%b0%b1-25/?utm_source=naver&utm_medium=partnership', 'link': 'https://www.vogue.co.kr/2023/07/14/%ec%9d%b4-%ec%97%ac%eb%a6%84-%ea%b0%80%ec%9e%a5-%ed%8c%a8%ec%85%94%eb%84%88%eb%b8%94%ed%95%9c-%eb%b0%94%ec%8a%a4%ec%bc%93-%eb%b0%b1-25/?utm_source=naver&utm_medium=partnership', 'description': '끌로에 - 우디 라지 바스켓 로고 리본 장식이 가장 먼저 눈에 들어오지만, 히든 포인트는 <b>가방</b> 하단에 동그란... 무뉴 - 토노 에크루 동그란 모양새가 귀여운 무뉴의 <b>가방</b>은 저항력이 강한 코끼리풀로 만들어 단단한 것이... ', 'pubDate': 'Fri, 14 Jul 2023 12:12:00 +0900'}, {'title': '아성다이소, &apos;초록휴식 시리즈&apos; 출시', 'originallink': 'http://www.rpm9.com/news/article.html?id=20230714090010', 'link': 'http://www.rpm9.com/news/article.html?id=20230714090010', 'description': '키덜트 문화로 &apos;인형 키링&apos;을 <b>가방</b>에 달고 다니는 어른들의 트렌드도 반영해 고리가 달린 △개구리 걸이인형도 선보인다. 욕실용품은 실용적인 아이템으로 구성했다. △접착식 칫솔걸이는 벽에 간편하게 붙여 쓰는... ', 'pubDate': 'Fri, 14 Jul 2023 12:12:00 +0900'}, {'title': '법정 출석 정유정
', 'description': 'A씨가 이에 놀라자 정유정은 &quot;장난이다&quot;라고 안심시켰고, <b>가방</b> 안에서 흉기를 꺼내 살해했다. 이후 자신의 집에 돌아가 여행용 <b>가방</b>(캐리어)을 가져와 시신을 담은 뒤 27일 새벽 경남 양산 한 공원 풀숲에 시신을 유기했다.... ', 'pubDate': 'Fri, 14 Jul 2023 11:56:00 +0900'}, {'title': '물가 고공행진에 도시락·텀블러 인기… &quot;락앤락 ...

# %%
i = 1
for link in links:
    save_name = 'data/images/img' + str(i)+'.jpg'
    
    try:
        urllib.request.urlretrieve(link, save_name)
        print(link, '저장됨')
        i += 1
    except:
        print(link, '저장실패')
# Out:
# http://shop1.phinf.naver.net/20220905_56/1662305324383Lw1lA_JPEG/69770020489969943_142234308.jpg 저장됨
# http://shop1.phinf.naver.net/20230617_79/1686997507306h0Nke_JPEG/2531576167695541_1871165144.jpg 저장됨
# http://shop1.phinf.naver.net/20230709_134/1688879078635sIPry_JPEG/B00N9MSH4C_image2.jpg 저장됨
# http://shopping.phinf.naver.net/main_4086881/40868815936.20230628174305.jpg 저장됨
# http://shop1.phinf.naver.net/20230517_218/1684295322235J8X4S_JPEG/45256268445171437_624405451.jpg 저장됨
# http://shopping.phinf.naver.net/main_4015648/40156488186.20230521200451.jpg 저장됨
# http://shop1.phinf.naver.net/20230310_22/16783768731121pdQY_JPEG/39337773126082837_1545763010.jpg 저장됨
# http://shopping.phinf.naver.net/main_3677290/36772905589.20230419141851.jpg 저장됨
# http://shop1.phinf.naver.net/20230324_219/1679658903582Rbh8F_JPEG/40619849784658432_690083232.jpg 저장됨
# http://shop1.phinf.naver.net/20230607_298/16861115452296yT0q_JPEG/87247380059282658_260796214.jpg 저장됨
# http://shop1.phinf.naver.net/20230524_142/1684911045962VHAMv_JPEG/202305241447594.jpg 저장됨
# http://shop1.phinf.naver.net/20230617_286/16869880445254Bn3z_JPEG/v1.jpg 저장됨
# http://shop1.phinf.naver.net/20230603_160/1685788762975417sN_JPEG/661892_0.jpg 저장됨
# http://shopping.phinf.naver.net/main_4079423/40794232867.20230629234733.jpg 저장됨
# http://shop1.phinf.naver.net/20230507_227/1683434727130eyGgL_JPEG/84570560947397986_380554137.jpg 저장됨
# http://shop1.phinf.naver.net/20230703_23/1688384839656UluwQ_JPEG/1682796472664322_542171564.jpg 저장됨
# http://shop1.phinf.naver.net/20230623_212/1687519757657beHGY_JPEG/1005446527450618_26359748.jpg 저장됨
# http://shop1.phinf.naver.net/20220204_196/1643939865676ndC6B_JPEG/45075764317095410_531015125.jpg 저장됨
# http://shop1.phinf.naver.net/20230423_101/1682202383876kN4yh_JPEG/14267128682042594_1075062716.jpg 저장됨
# http://shop1.phinf.naver.net/20230310_146/1678443124130qm4RX_JPEG/39404024150476640_244111316.jpg 저장됨
# http://shop1.phinf.naver.net/20230509_112/1683586534154a1Vl0_JPEG/e0169c41b41b48d58bae161ed72a192d.jpg 저장됨
# http://shop1.phinf.naver.net/20230603_252/1685758451011DGa6L_JPEG/13182202939837932_283155916.jpg 저장됨
# http://shop1.phinf.naver.net/20230526_127/1685092708164f2SPn_JPEG/2865988306959317_1221277184.jpg 저장됨
# http://shop1.phinf.naver.net/20230515_50/1684121029414ExWL5_JPEG/132460433_M_500.jpg 저장됨
# http://shop1.phinf.naver.net/20230629_216/1687964742332EDlLT_JPEG/89100526048357424_2143841975.jpg 저장됨
# http://shop1.phinf.naver.net/20230324_159/1679623071276ccFNB_JPEG/40583990197865855_933186556.jpg 저장됨
# http://shopping.phinf.naver.net/main_4079422/40794220170.20230624183259.jpg 저장됨
# http://shop1.phinf.naver.net/20221208_209/1670466330739ggdwF_JPEG/ahM03_120135_7.jpg 저장됨
# http://shop1.phinf.naver.net/20230421_92/1682077692363qykyC_JPEG/B0BVYG784T_image7.jpg 저장됨
# http://shopping.phinf.naver.net/main_3610799/36107993238.1.20230614125715.jpg 저장됨
# http://shop1.phinf.naver.net/20230524_252/1684856291773D9cpk_JPEG/35207721949413966_1367466624.jpg 저장됨
# http://shop1.phinf.naver.net/20230706_57/1688634172838c6pf8_JPEG/1831895169157557_1553935308.jpg 저장됨
# http://shop1.phinf.naver.net/20221223_290/1671806881847XGO2a_JPEG/32767814769832686_914720080.jpg 저장됨
# http://shop1.phinf.naver.net/20230616_111/1686921445832TlVsD_JPEG/32938029664259573_1533872694.jpg 저장됨
# http://shop1.phinf.naver.net/20220426_166/165095894192086yDE_JPEG/52094787129131329_887978385.JPG 저장됨
# http://shopping.phinf.naver.net/main_3583202/35832021979.20221114162541.jpg 저장됨
# http://shop1.phinf.naver.net/20230709_14/1688909646871W90Ch_JPEG/image.jpg 저장됨
# http://shop1.phinf.naver.net/20200129_279/1580304202640rC2n5_JPEG/17656371646479963_1237800352.jpg 저장됨
# http://shop1.phinf.naver.net/20230709_126/1688910790034FEiCm_JPEG/image.jpg 저장됨
# http://shop1.phinf.naver.net/20230709_223/1688908321816vp9VY_JPEG/image.jpg 저장됨
# http://shop1.phinf.naver.net/20230609_179/1686241753391uWQ2r_JPEG/202306082348383.jpg 저장됨
# http://shop1.phinf.naver.net/20230427_139/1682527821244n8Lvu_JPEG/43488754163182038_1568979967.jpg 저장됨
# http://shop1.phinf.naver.net/20220314_261/164725661563130uxM_JPEG/54721325741440491_712682897.jpg 저장됨
# http://shopping.phinf.naver.net/main_4089004/40890046683.20230629185056.jpg 저장됨
# http://shop1.phinf.naver.net/20230109_252/16732250081031R8lp_JPEG/34185941024171994_512338420.jpg 저장됨
# http://shopping.phinf.naver.net/main_4004090/40040905632.20230515201007.jpg 저장됨
# http://shop1.phinf.naver.net/20230124_12/1674543172763buzPj_JPEG/3ee57e3611614e7cb69e52646c302404.jpg 저장됨

# %%
from wordcloud import WordCloud
font_path='c:/Windows/Fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
Okt().pos(title)
# Out:
# [('“', 'Foreign'),
#  ('농촌', 'Noun'),
#  ('관광', 'Noun'),
#  ('좋아', 'Adjective'),
#  ('”', 'Foreign'),
#  ('68%', 'Number'),
#  ('…', 'Foreign'),
#  ('“', 'Foreign'),
#  ('물가', 'Noun'),
#  ('비싸다', 'Adjective'),
#  ('”', 'Foreign'),
#  ('도', 'Noun'),
#  ('61%', 'Number'),
#  ('크리스피크림', 'Noun'),
#  ('도넛', 'Noun'),
#  (',', 'Punctuation'),
#  ('<', 'Punctuation'),
#  ('b', 'Alpha'),
#  ('>', 'Punctuation'),
#  ('여름', 'Noun'),
#  ('</', 'Punctuation'),
#  ('b', 'Alpha'),
#  ('>', 'Punctuation'),
#  ('수영장', 'Noun'),
#  ('떠오르는', 'Verb'),
#  ('신제품', 'Noun'),
#  ('5', 'Number'),
#  ('종', 'Noun'),
#  ('출시', 'Noun'),
#  ('유명', 'Noun'),
#  ('섭', 'Noun'),
#  ('에어', 'Noun'),
#  ('프레', 'Noun'),
#  ('미아', 'Noun'),
#  ('대표', 'Noun'),
#  (',', 'Punctuation'),
#  ('임', 'Noun'),
#  ('직원', 'Noun'),
#  ('과', 'Josa'),
#  ('기내', 'Noun'),
#  ('청소', 'Noun'),
#  ('…', 'Punctuation'),
#  ('“', 'Foreign'),
#  ('장시간', 'Noun'),
#  ('비행', 'Noun'),
#  ('도', 'Josa'),
#  ('쾌적하게', 'Adjective'),
#  ('”', 'Foreign'),
#  ('하림', 'Noun'),
#  ('X', 'Alpha'),
#  ('반', 'Modifier'),
#  ('얀', 'Noun'),
#  ('트리', 'Noun'),
#  ('서울', 'Noun'),
#  ('등', 'Noun'),
#  ('협업', 'Noun'),
#  ('등', 'Noun'),
#  ('식품', 'Noun'),
#  ('업계', 'Noun'),
#  ('-', 'Punctuation'),
#  ('호텔', 'Noun'),
#  ('업계', 'Noun'),
#  ('&', 'Punctuation'),
#  ('apos', 'Alpha'),
#  (';', 'Punctuation'),
#  ('미식', 'Noun'),
#  ('호캉스족', 'Noun'),
#  ('&', 'Punctuation'),
#  ('apos', 'Alpha'),
#  (';', 'Punctuation'),
#  ('공략', 'Noun'),
#  ('나서', 'Verb'),
#  ('[', 'Punctuation'),
#  ('라이센스', 'Noun'),
#  ('라이프', 'Noun'),
#  ('PICK', 'Alpha'),
#  (']', 'Punctuation'),
#  ('제주', 'Noun'),
#  ('신라', 'Noun'),
#  ('호텔', 'Noun'),
#  ('·', 'Punctuation'),
#  ('여기어', 'Verb'),
#  ('때', 'Noun'),
#  ('·', 'Punctuation'),
#  ('오션월드', 'Noun'),
#  ('인', 'Josa'),
#  ('천시', 'Noun'),
#  (',', 'Punctuation'),
#  ('국내외', 'Noun'),
#  ('최초', 'Noun'),
#  ('드론', 'Noun'),
#  ('복합', 'Noun'),
#  ('탐지', 'Noun'),
#  ('체계', 'Noun'),
#  ('스마트', 'Noun'),
#  ('해양', 'Noun'),
#  ('환경', 'Noun'),
#  ('관리', 'Noun'),
#  ('시스템', 'Noun'),
#  ('구축', 'Noun'),
#  ('양양군', 'Noun'),
#  (',', 'Punctuation'),
#  ('<', 'Punctuation'),
#  ('b', 'Alpha'),
#  ('>', 'Punctuation'),
#  ('여름', 'Noun'),
#  ('휴가', 'Noun'),
#  ('</', 'Punctuation'),
#  ('b', 'Alpha'),
#  ('>', 'Punctuation'),
#  ('철', 'Noun'),
#  ('맞아', 'Verb'),
#  ('피', 'Noun'),
#  ('서지', 'Noun'),
#  ('물가', 'Noun'),
#  ('안정', 'Noun'),
#  ('관리', 'Noun'),
#  ('추진', 'Noun'),
#  ('직장인', 'Noun'),
#  ('10', 'Number'),
#  ('명중', 'Noun'),
#  ('4', 'Number'),
#  ('명', 'Noun'),
#  ('&', 'Punctuation'),
#  ('quot', 'Alpha'),
#  (';<', 'Punctuation'),
#  ('b', 'Alpha'),
#  ('>', 'Punctuation'),
#  ('여름', 'Noun'),
#  ('휴가', 'Noun'),
#  ('</', 'Punctuation'),
#  ('b', 'Alpha'),
#  ('>', 'Punctuation'),
#  ('계획', 'Noun'),
#  ('미정', 'Noun'),
#  ('&', 'Punctuation'),
#  ('quot', 'Alpha'),
#  (';···', 'Punctuation'),
#  ('선호', 'Noun'),
#  ('지', 'Josa'),
#  ('1', 'Number'),
#  ('위', 'Noun'),
#  ('는', 'Josa'),
#  ('&', 'Punctuation'),
#  ('apos', 'Alpha'),
#  (';', 'Punctuation'),
#  ('바다', 'Noun'),
#  ('&', 'Punctuation'),
#  ('apos', 'Alpha'),
#  (';<', 'Punctuation'),
#  ('b', 'Alpha'),
#  ('>', 'Punctuation'),
#  ('여름', 'Noun'),
#  ('휴가', 'Noun'),
#  ('</', 'Punctuation'),
#  ('b', 'Alpha'),
#  ('>', 'Punctuation'),
#  ('제', 'Modifier'),
#  ('값', 'Noun'),
#  ('주고', 'Verb'),
#  ('가면', 'Noun'),
#  ('손해', 'Noun'),
#  ('…', 'Punctuation'),
#  ('워터파크', 'Noun'),
#  ('반값', 'Noun'),
#  ('에', 'Josa'),
#  ('항공권', 'Noun'),
#  ('할인', 'Noun'),
#  ('까지', 'Josa'),
#  ('여수시', 'Noun'),
#  ('낭만', 'Noun'),
#  ('포차', 'Noun'),
#  ('운영', 'Noun'),
#  ('협의', 'Noun'),
#  ('회', 'Noun'),
#  (',', 'Punctuation'),
#  ('&', 'Punctuation'),
#  ('apos', 'Alpha'),
#  (';', 'Punctuation'),
#  ('바가지요금', 'Noun'),
#  ('근절', 'Noun'),
#  ('‧', 'Foreign'),
#  ('친절', 'Noun'),
#  ('서비스', 'Noun'),
#  ('&', 'Punctuation'),
#  ('apos', 'Alpha'),
#  (';', 'Punctuation'),
#  ('다짐', 'Noun'),
#  ('결의', 'Noun')]

# %%
wc = WordCloud(width=1000, height=1000, background_color='white', font_path=font_path)
plt.imshow(wc.generate_from_frequencies(title))
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 2
#       1 wc = WordCloud(width=1000, height=1000, background_color='white', font_path=font_path)
# ----> 2 plt.imshow(wc.generate_from_frequencies(title))
#       3 plt.axis('off')
#       4 plt.show()
#
# File c:\Users\it\anaconda3\lib\site-packages\wordcloud\wordcloud.py:408, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     392 """Create a word_cloud from words and frequencies.
#     393
#     394 Parameters
#    (...)
#     405
#     406 """
#     407 # make sure frequencies are sorted and normalized
# --> 408 frequencies = sorted(frequencies.items(), key=itemgetter(1), reverse=True)
#     409 if len(frequencies) <= 0:
#     410     raise ValueError("We need at least 1 word to plot a word cloud, "
#     411                      "got %d." % len(frequencies))
#
# AttributeError: 'str' object has no attribute 'items'
