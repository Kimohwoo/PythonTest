# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
x = pd.Series([4,3,2,7,5])
print(x)
# Out:
# 0    4
# 1    3
# 2    2
# 3    7
# 4    5
# dtype: int64

# %%
x.plot()
# Out:
# <Axes: >

# %%
data1 = np.random.rand(50)
data2 = np.random.randn(50)
data3 = np.random.randint(1, 100, 10)
print(data1)
print(data2)
print(data3)
# Out:
# [0.45768526 0.71250745 0.39099488 0.41827834 0.59408483 0.06415376
#  0.3354107  0.96215114 0.60024274 0.79922197 0.23898634 0.98433425
#  0.55860831 0.10100974 0.30988338 0.30213172 0.67358451 0.65361608
#  0.72418206 0.71233115 0.24533366 0.96293006 0.42243733 0.76169193
#  0.28182994 0.49321495 0.0336225  0.51436829 0.77750147 0.86103752
#  0.46756884 0.61982094 0.07836616 0.28463585 0.1458561  0.13283831
#  0.93482604 0.17454398 0.71817142 0.92845054 0.37451836 0.30690901
#  0.81557009 0.16294392 0.36792057 0.93753641 0.7937112  0.23447532
#  0.31669472 0.80802706]
# [ 0.31622611  1.28260222 -0.65669701  0.32902632 -1.5380647   0.44690461
#  -0.97120269 -1.20648352  0.85427307 -0.00365318 -0.53152016 -0.26171569
#   0.73964119  0.42943266 -1.0751791  -0.50908819 -0.05074406 -0.66343636
#  -0.60473251 -2.1797558  -1.30329959 -2.57215354  1.5729831  -0.88212224
#  -2.28978325 -1.42763796  0.10612229 -0.49788696 -0.00369087 -2.00379109
#  -0.79541758 -1.33169774 -1.0355557  -0.24152756 -0.79027123 -0.70510969
#  -1.98953298 -0.10944175  0.27605082 -0.22810428 -0.07370903  0.00498239
#   1.3141049   0.50186435  0.47370857 -0.05926252 -1.74179391 -0.79475482
#  -1.22658487 -0.03746991]
# [28 93 86 96 44  4 12 66 55 29]

# %%
data4 = np.random.rand(10, 4)
# print(data4)
df = pd.DataFrame(data4, columns=['A','B','C','D'])
df.plot()
print(df)
# Out:
#           A         B         C         D
# 0  0.291646  0.370280  0.628760  0.040856
# 1  0.531807  0.870059  0.022903  0.363629
# 2  0.923764  0.269296  0.971166  0.570803
# 3  0.072231  0.369208  0.199224  0.044257
# 4  0.090219  0.359883  0.755213  0.773979
# 5  0.946831  0.261674  0.091951  0.543825
# 6  0.503668  0.885508  0.248631  0.047889
# 7  0.889622  0.951520  0.039265  0.604388
# 8  0.556381  0.840913  0.078602  0.258028
# 9  0.007887  0.575027  0.367128  0.058982

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
df.plot(kind='barh', stacked=True)
# Out:
# <Axes: >

# %%
df.plot(kind='area')
# Out:
# <Axes: >

# %%
sri = pd.Series([5,2,7,3,6], index=['가','나','다','라','마'], name='파이차트')
print(sri)
# Out:
# 가    5
# 나    2
# 다    7
# 라    3
# 마    6
# Name: 파이차트, dtype: int64

# %%
from matplotlib import rc, font_manager
fontname = "C:/Windows/Fonts/batang.ttc"
font_name = font_manager.FontProperties(fname=fontname).get_name()
rc('font',family=font_name)

# %%
sri.plot(kind='pie', autopct = '%.2f', fontsize=12, figsize=(5,5))
# Out:
# <Axes: ylabel='파이차트'>

# %%
plt.rcParams['axes.unicode_minus']=False

# %%
s1 = pd.Series(np.random.normal(0, 100, size=200))
s1.hist(bins=100)
# Out:
# <Axes: >

# %%
x1 = np.random.normal(1, 1, size=(100,1))
x2 = np.random.normal(-2, 4, size=(100,1))
x = np.concatenate((x1, x2), axis=1) #axis=1 가로, aixs=0 세로
x
# Out:
# array([[ -0.09969046,  -0.8041056 ],
#        [  0.22093545,   0.62971131],
#        [ -1.11836911,   0.71527687],
#        [  4.28150438,  -1.16281059],
#        [  1.19438863,  -4.87104854],
#        [  0.15078839,  -5.40703879],
#        [ -0.0536018 ,   1.65327263],
#        [  1.71971065,  -6.15754208],
#        [  0.61524236,  -0.64291071],
#        [ -0.93843159,  -1.87461141],
#        [  0.83244594,   2.38145107],
#        [  1.5279029 ,  -3.76841522],
#        [  0.60405103,  -1.12658116],
#        [  1.90826845,  -2.08956534],
#        [  0.89962132, -10.33923065],
#        [ -1.58377809,  -2.45717861],
#        [  1.48206218,  -0.67682938],
#        [ -0.1729588 ,  -0.49028108],
#        [  0.38794367,  -2.11068071],
#        [  2.30570729,  -4.38338226],
#        [  2.12273167, -12.05152482],
#        [ -0.75882817,  -4.31649878],
#        [  0.35620618,   1.2234768 ],
#        [  3.14413187,   2.92298485],
#        [  1.20236241,   1.89548576],
#        [  1.59088353, -13.74856683],
#        [  1.05451188,   1.83591319],
#        [  0.7847478 ,  -0.11539725],
#        [ -2.04619422,  -9.75539323],
#        [  1.0187621 ,  -6.50504442],
#        [  0.95640966,  -5.79494292],
#        [  0.02464065,   0.25390736],
#        [ -0.12268026, -11.77772678],
#        [  1.77086381,   2.16936854],
#        [  1.13425644,  -3.4864369 ],
#        [  2.93401311,  -7.11814978],
#        [  1.45683467,  -4.50805881],
#        [  0.28193139,   0.55740523],
#        [  1.64803613,  -3.68226515],
#        [  0.57277855,  -1.15802019],
#        [  1.54152603,  -1.08909527],
#        [ -0.7657655 ,  -5.13962926],
#        [  1.12555829,  -7.45632332],
#        [ -0.11137173,  -6.71916924],
#        [  0.6443359 ,  -5.25502623],
#        [ -0.27500088,   3.94649706],
#        [  0.27282522,  -3.50003458],
#        [  3.2813678 ,  -1.70819512],
#        [  1.01396701,   1.28294675],
#        [  2.7013887 ,   4.14979108],
#        [  1.02884064,   2.69859922],
#        [  0.42404548,  -0.50206865],
#        [  2.89038603,  -1.12346259],
#        [  0.62602671,   2.4940942 ],
#        [  0.73155793,  -6.62039206],
#        [  1.30553955,  -5.48759453],
#        [  0.79762407,  -6.64856341],
#        [ -0.05299339,  -2.52744996],
#        [  1.12571209,   4.78378353],
#        [ -0.62640875,   3.54007048],
#        [  2.14436481,  -2.1606617 ],
#        [  3.11624754,  -6.09997188],
#        [  1.76465271,  -7.95538154],
#        [  1.30202952,  -5.3549124 ],
#        [  0.91821464,   0.82295211],
#        [  1.32749525,   3.73140777],
#        [  1.21878606,  -2.51101003],
#        [  1.63309228,   0.69795443],
#        [ -0.04255285,   1.78925643],
#        [  0.3788535 ,  -7.72725967],
#        [  0.18372068,   6.2165686 ],
#        [  1.70745119,  -2.34963952],
#        [  1.70204796,  -6.25137381],
#        [ -0.05903309,  -3.27976113],
#        [  0.59102079,   0.65151587],
#        [  0.95667631,   5.12062505],
#        [  2.24507484,  -3.05626524],
#        [  0.72789132,  -0.43735925],
#        [  0.93598146,  -0.53979278],
#        [  0.15747296,  -3.22880257],
#        [  0.42223309,   1.31259794],
#        [  2.16278139,   4.11027795],
#        [  1.14849743,  -5.64652463],
#        [  0.79553175,   0.8077695 ],
#        [  1.17509776,  -5.68980973],
#        [  0.47878055,  -2.74759374],
#        [  1.64213532,  -5.97592242],
#        [  1.12475034,   3.53894472],
#        [  2.01170104,  -3.91251692],
#        [  0.57538112,  -5.2969638 ],
#        [  0.90722295,  -3.0356758 ],
#        [  2.80726768,   2.17070858],
#        [  0.51902343,   0.39883196],
#        [  2.88374811,   0.78961153],
#        [  0.33858177,   0.61621076],
#        [  0.88532843,  -8.25304761],
#        [  1.74425004,  -2.47077512],
#        [  0.43129916,   1.76763375],
#        [  0.52490721,  -5.03083375],
#        [ -0.78822928,   1.52672192]])

# %%
df=pd.DataFrame(x, columns=['x1','x2'])
#상관 계수 출력 : 1에 가까울 수록 상관관계가 높음!!
df['x1'].corr(df['x2'])
# Out:
# -0.019846208705335686

# %%
x=np.arange(1,6)
y=np.arange(10,60,10)
data={'x':x,'y':y}
df2=pd.DataFrame(data); df2
# Out:
#    x   y
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50

# %%
df2['x'].corr(df2['y'])
# Out:
# 1.0

# %%
plt.scatter(x,y)

# %%
filename = 'data/temperature_2014.csv'
df = pd.read_csv(filename)
df['PST'] = pd.to_datetime(df['PST'])
df.info()
fig = plt.figure(dpi=128, figsize=(10,6))
plt.plot(df['PST'], df['Max TemperatureF'], c="red", alpha=0.5)
plt.plot(df['PST'], df['Min TemperatureF'], c="green", alpha=0.5)
plt.fill_between(df['PST'], df['Max TemperatureF'], df['Min TemperatureF'], facecolor='blue', alpha=0.2)
plt.title("온도 통계", fontsize=20)
plt.xlabel('기간', fontsize=16)
plt.ylabel('온도', fontsize=16)
plt.tick_params(axis='both', labelsize=16)
plt.savefig('data/chart.png', dpi=400, bbox_inches='tight')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PST                         360 non-null    datetime64[ns]
#  1   Max TemperatureF            359 non-null    float64
#  2   Mean TemperatureF           359 non-null    float64
#  3   Min TemperatureF            359 non-null    float64
#  4   Max Dew PointF              359 non-null    float64
#  5   MeanDew PointF              359 non-null    float64
#  6   Min DewpointF               359 non-null    float64
#  7   Max Humidity                359 non-null    float64
#  8    Mean Humidity              359 non-null    float64
#  9    Min Humidity               359 non-null    float64
#  10   Max Sea Level PressureIn   359 non-null    float64
#  11   Mean Sea Level PressureIn  359 non-null    float64
#  12   Min Sea Level PressureIn   359 non-null    float64
#  13   Max VisibilityMiles        355 non-null    float64
#  14   Mean VisibilityMiles       355 non-null    float64
#  15   Min VisibilityMiles        355 non-null    float64
#  16   Max Wind SpeedMPH          359 non-null    float64
#  17   Mean Wind SpeedMPH         359 non-null    float64
#  18   Max Gust SpeedMPH          211 non-null    float64
#  19  PrecipitationIn             360 non-null    float64
#  20   CloudCover                 343 non-null    float64
#  21   Events                     18 non-null     object
#  22   WindDirDegrees             360 non-null    int64
# dtypes: datetime64[ns](1), float64(20), int64(1), object(1)
# memory usage: 64.8+ KB

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot([1,2,3,4], [10, 20, 30, 40])
plt.subplot(2,2,2)
plt.plot([10,20,30,40],[10,20,30,40])
plt.subplot(2,2,3)
plt.plot([100,200,300,400],[10,20,30,40])
plt.subplot(2,2,4)
plt.plot([11,12,13,14],[10,20,30,40])
plt.show()

# %%
plt.plot([1,2,3,4], [1,2,3,4])
plt.xlabel('x축')
plt.ylabel('y축')
plt.title('matplotlib 활용')
plt.text(2.1, 2.7, '평균:2.5')
plt.grid(True)
plt.show()
